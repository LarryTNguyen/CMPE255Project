# %% [markdown]
# # Data Cleaning
#
# This notebook is primarily to explore and clean the datasets we are working on.

# %% [markdown]
# ## Citibike Data

# %%
import pandas as pd

citibike_db = pd.read_csv('Datasets\Citibike\\202501-citibike-tripdata_1.csv')
citibike_db.head()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\C'
# <>:3: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\larry\AppData\Local\Temp\ipykernel_34812\3844117713.py:3: SyntaxWarning: invalid escape sequence '\C'
#   citibike_db = pd.read_csv('Datasets\Citibike\\202501-citibike-tripdata_1.csv')
# C:\Users\larry\AppData\Local\Temp\ipykernel_34812\3844117713.py:3: DtypeWarning: Columns (0: start_station_id, 1: end_station_id) have mixed types. Specify dtype option on import or set low_memory=False.
#   citibike_db = pd.read_csv('Datasets\Citibike\\202501-citibike-tripdata_1.csv')
#             ride_id  rideable_type               started_at  \
# 0  ACCC919B5A3CD9AD  electric_bike  2025-01-01 14:52:26.542
# 1  1FABDF3EE40FCB0E   classic_bike  2025-01-10 05:03:13.646
# 2  88F0F3CFCBC79652   classic_bike  2025-01-13 13:40:17.630
# 3  6FDE4E191D58E453  electric_bike  2025-01-10 08:29:16.996
# 4  E9B03B9F77A85455  electric_bike  2025-01-11 18:59:48.427
#
# ...

# %%
citibike_db = citibike_db.drop(columns=['start_station_id', 'end_station_id', 'ride_id', 'member_casual'])
citibike_db.head()
# Out:
#    rideable_type               started_at                 ended_at  \
# 0  electric_bike  2025-01-01 14:52:26.542  2025-01-01 14:59:53.427
# 1   classic_bike  2025-01-10 05:03:13.646  2025-01-10 05:13:13.331
# 2   classic_bike  2025-01-13 13:40:17.630  2025-01-13 13:47:05.817
# 3  electric_bike  2025-01-10 08:29:16.996  2025-01-10 08:34:49.360
# 4  electric_bike  2025-01-11 18:59:48.427  2025-01-11 19:13:21.292
#
#         start_station_name         end_station_name  start_lat  start_lng  \
# 0          W 20 St & 7 Ave          E 10 St & 2 Ave  40.742388 -73.997262
# 1          W 20 St & 7 Ave          E 25 St & 1 Ave  40.742388 -73.997262
# 2  St James Pl & Oliver St   Fulton St & William St  40.713079 -73.998512
# 3  St James Pl & Oliver St   Fulton St & William St  40.713079 -73.998512
# 4          E 33 St & 1 Ave  Allen St & Rivington St  40.743227 -73.974498
#
#      end_lat    end_lng
# 0  40.729708 -73.986598
# 1  40.738177 -73.977387
# 2  40.709601 -74.006551
# ...

# %%
citibike_db = citibike_db.dropna()
citibike_db.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 997581 entries, 0 to 999999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   rideable_type       997581 non-null  str
#  1   started_at          997581 non-null  str
#  2   ended_at            997581 non-null  str
#  3   start_station_name  997581 non-null  str
#  4   end_station_name    997581 non-null  str
#  5   start_lat           997581 non-null  float64
#  6   start_lng           997581 non-null  float64
#  7   end_lat             997581 non-null  float64
#  8   end_lng             997581 non-null  float64
# dtypes: float64(4), str(5)
# memory usage: 76.1 MB
